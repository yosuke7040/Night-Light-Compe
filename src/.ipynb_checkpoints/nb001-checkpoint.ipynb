# %% [markdown]
# # EDA

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib_venn import venn2
from ptitprince import RainCloud

from pandas_profiling import ProfileReport

print(os.getcwd())
# Out:
# /src/Solafune/夜間光データから土地価格を予測/src

# %%
INPUT_DIR = '/src/Solafune/夜間光データから土地価格を予測/data/inputs/'
OUTPUT_DIR = '/src/Solafune/夜間光データから土地価格を予測/data/outputs/'

os.makedirs(OUTPUT_DIR, exist_ok=True)

train_df = pd.read_csv(os.path.join(INPUT_DIR, 'TrainDataSet.csv'))
test_df = pd.read_csv(os.path.join(INPUT_DIR, 'EvaluationData.csv'))

# %%
train_df.T
# Out:
#                         0            1            2            3      \
# PlaceID           1128.000000  1128.000000  1128.000000  1128.000000
# Year              1993.000000  1994.000000  1995.000000  1996.000000
# AverageLandPrice   740.909091   739.390909   739.390909   739.390909
# MeanLight           57.571430    62.714287    61.857143    61.714287
# SumLight           403.000000   439.000000   433.000000   432.000000
#
#                         4            5            6            7      \
# PlaceID           1128.000000  1128.000000  1128.000000  1128.000000
# Year              1997.000000  1998.000000  1999.000000  2000.000000
# AverageLandPrice   739.390909   739.390909   724.236364   782.045455
# MeanLight           62.857143    60.857143    60.857143    61.000000
# SumLight           440.000000   426.000000   426.000000   427.000000
#
#                         8            9      ...        21873        21874  \
# PlaceID           1128.000000  1128.000000  ...  1141.000000  1141.000000
# Year              2001.000000  2002.000000  ...  2004.000000  2005.000000
# AverageLandPrice   757.272727   722.727273  ...   120.727273   117.181818
# MeanLight           59.428570    61.857143  ...    11.617977     9.820225
# SumLight           416.000000   433.000000  ...  1034.000000   874.000000
#
#                         21875        21876        21877        21878  \
# PlaceID           1141.000000  1141.000000  1141.000000  1141.000000
# Year              2006.000000  2007.000000  2008.000000  2009.000000
# AverageLandPrice   114.418182   109.600000   105.818182    99.818182
# MeanLight           10.202248    12.146068    11.640450    10.978724
# SumLight           908.000000  1081.000000  1036.000000  1032.000000
#
#                         21879        21880        21881        21882
# PlaceID           1141.000000  1141.000000  1141.000000  1141.000000
# Year              2010.000000  2011.000000  2012.000000  2013.000000
# AverageLandPrice    94.000000    89.363636    85.000000    80.545455
# MeanLight           16.734043    12.595745    13.775281    13.011236
# SumLight          1573.000000  1184.000000  1226.000000  1158.000000
#
# [5 rows x 21883 columns]

# %%
#report = ProfileReport(train_df)
#report.to_file(os.path.join(OUTPUT_DIR, 'train_report.html'))

# %%
columns = test_df.columns
n_figs = len(columns)
n_cols = 4

fig, axes = plt.subplots(figsize=(n_cols*3, 3), ncols=n_cols, nrows=1)

for c, ax in zip(columns, axes.ravel()):
    venn2(
        subsets=(set(train_df[c].unique()), set(test_df[c].unique())),
        set_labels=('Train', 'Test'),
        ax=ax
    )
    ax.set_title(c)

# %% [markdown]
# trainとtestの分布全然違うな・・・
# cvの切り方とか、特徴量の作り方難しそう

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21883 entries, 0 to 21882
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   PlaceID           21883 non-null  int64
#  1   Year              21883 non-null  int64
#  2   AverageLandPrice  21883 non-null  float64
#  3   MeanLight         21883 non-null  float64
#  4   SumLight          21883 non-null  float64
# dtypes: float64(3), int64(2)
# memory usage: 854.9 KB

# %%
idx = train_df['PlaceID'] == 1128.0
train_df[idx].sort_values('AverageLandPrice', ascending=False)
# Out:
#     PlaceID  Year  AverageLandPrice  MeanLight  SumLight
# 7      1128  2000        782.045455  61.000000     427.0
# 8      1128  2001        757.272727  59.428570     416.0
# 0      1128  1993        740.909091  57.571430     403.0
# 1      1128  1994        739.390909  62.714287     439.0
# 2      1128  1995        739.390909  61.857143     433.0
# 3      1128  1996        739.390909  61.714287     432.0
# 4      1128  1997        739.390909  62.857143     440.0
# 5      1128  1998        739.390909  60.857143     426.0
# 6      1128  1999        724.236364  60.857143     426.0
# 9      1128  2002        722.727273  61.857143     433.0
# 10     1128  2003        670.545455  58.285713     408.0
# 12     1128  2005        618.063636  61.000000     427.0
# 11     1128  2004        599.545455  61.000000     427.0
# 13     1128  2006        581.363636  61.000000     427.0
# 14     1128  2007        575.654545  61.142857     428.0
# 15     1128  2008        553.527273  62.428570     437.0
# 16     1128  2009        526.154545  59.000000     413.0
# 17     1128  2010        500.200000  61.857143     433.0
# 18     1128  2011        473.427273  61.285713     429.0
# 19     1128  2012        450.500000  61.000000     427.0
# 20     1128  2013        429.490909  60.857143     426.0

# %% [markdown]
# 2000,2001年が高騰しとるけどなんでや？
# そのあと急降下しとるけども、災害とかあったのか？
# もしかしてバブルが1993とからへんか？
# いやSumLightが変わってないから人の量は減ってない？
# でも工場とかならわからんな

# %%
train_df.sort_values('AverageLandPrice', ascending=False).head(20)
# Out:
#        PlaceID  Year  AverageLandPrice  MeanLight  SumLight
# 9849       640  1992     112229.090909       63.0     630.0
# 20453      118  1992      98221.209091       63.0     945.0
# 9850       640  1993      91392.045455       63.0     630.0
# 10047      135  1992      82750.000000       63.0    1008.0
# 20454      118  1993      72641.645455       63.0     945.0
# 9851       640  1994      64252.518182       63.0     630.0
# 17989     1522  1992      62187.272727       63.0     693.0
# 10048      135  1993      58532.081818       63.0    1008.0
# 20455      118  1994      46379.636364       63.0     945.0
# 17990     1522  1993      46353.290909       63.0     693.0
# 9852       640  1995      45561.763636       63.0     630.0
# 9865       640  2008      42258.236364       63.0     630.0
# 9866       640  2009      39790.627273       63.0     630.0
# 10049      135  1994      38663.381818       63.0    1008.0
# 9864       640  2007      37105.045455       63.0     630.0
# 9870       640  2013      36486.863636       63.0     630.0
# 9867       640  2010      36208.809091       63.0     630.0
# 9868       640  2011      35176.854545       63.0     630.0
# 9869       640  2012      34206.945455       63.0     630.0
# 10063      135  2008      34123.154545       63.0    1008.0

# %%
idx = train_df['PlaceID'] == 640
train_df[idx]
# Out:
#       PlaceID  Year  AverageLandPrice  MeanLight  SumLight
# 9849      640  1992     112229.090909       63.0     630.0
# 9850      640  1993      91392.045455       63.0     630.0
# 9851      640  1994      64252.518182       63.0     630.0
# 9852      640  1995      45561.763636       63.0     630.0
# 9853      640  1996      33750.000000       62.5     625.0
# 9854      640  1997      28686.363636       63.0     630.0
# 9855      640  1998      27831.818182       63.0     630.0
# 9856      640  1999      26128.409091       63.0     630.0
# 9857      640  2000      24690.000000       63.0     630.0
# 9858      640  2001      23225.000000       63.0     630.0
# 9859      640  2002      28861.318182       63.0     630.0
# 9860      640  2003      28335.436364       63.0     630.0
# 9861      640  2004      28331.118182       63.0     630.0
# 9862      640  2005      28699.236364       63.0     630.0
# 9863      640  2006      31072.272727       63.0     630.0
# 9864      640  2007      37105.045455       63.0     630.0
# 9865      640  2008      42258.236364       63.0     630.0
# 9866      640  2009      39790.627273       63.0     630.0
# 9867      640  2010      36208.809091       63.0     630.0
# 9868      640  2011      35176.854545       63.0     630.0
# 9869      640  2012      34206.945455       63.0     630.0
# 9870      640  2013      36486.863636       63.0     630.0

# %% [markdown]
# ??????
# 1996年だけわずかに光量が減ったがあとはずっと一緒
# なのにデータ取り始めたから年々値段は下がっている

# %%
idx = train_df['MeanLight'] == 0
train_df[idx].sort_values('AverageLandPrice', ascending=False).head(20)
# Out:
#        PlaceID  Year  AverageLandPrice  MeanLight  SumLight
# 21333      918  1992        539.090909        0.0       0.0
# 21776     1334  1995        245.454545        0.0       0.0
# 21774     1334  1993        245.454545        0.0       0.0
# 21777     1334  1996        245.454545        0.0       0.0
# 21780     1334  1999        245.454545        0.0       0.0
# 21781     1334  2000        245.454545        0.0       0.0
# 21782     1334  2001        236.363636        0.0       0.0
# 9695       416  1992        183.636364        0.0       0.0
# 15085      473  1992        172.727273        0.0       0.0
# 21787     1334  2006        159.090909        0.0       0.0
# 21788     1334  2007        154.545455        0.0       0.0
# 21789     1334  2008        152.727273        0.0       0.0
# 21790     1334  2009        150.909091        0.0       0.0
# 21791     1334  2010        149.090909        0.0       0.0
# 8355       963  1994        146.363636        0.0       0.0
# 8353       963  1992        146.000000        0.0       0.0
# 21792     1334  2011        145.454545        0.0       0.0
# 21793     1334  2012        143.636364        0.0       0.0
# 10949     1575  1992        143.181818        0.0       0.0
# 21794     1334  2013        139.090909        0.0       0.0

# %% [markdown]
# 合計値が０ということは、山とか海とか？
# 日本の土地とかなら山っぽいし、年々価値は下がっていっている気がするな。
# - 地価公示（国土交通省）を元に弊社が集計、加工したものを使用しています。
# とのこと

# %%
train_df.groupby('Year').sum()
# Out:
#       PlaceID  AverageLandPrice     MeanLight   SumLight
# Year
# 1992   729210      1.520899e+06  21339.529731  2344428.0
# 1993   774814      1.294071e+06  21735.527688  2471884.0
# 1994   797235      1.113501e+06  24161.181651  2632165.0
# 1995   800632      1.013415e+06  24724.289220  2842279.0
# 1996   804563      9.193162e+05  24977.396104  2884904.0
# 1997   808032      8.705321e+05  22851.011235  2420674.0
# 1998   811664      8.334445e+05  23321.001720  2593116.0
# 1999   814050      7.856966e+05  23381.638647  2606185.0
# 2000   818088      7.423383e+05  25446.189956  2974842.0
# 2001   819345      7.067791e+05  24987.008371  2955340.0
# 2002   819345      6.787340e+05  25216.266879  2927167.0
# 2003   820435      6.411382e+05  21056.569481  2252336.0
# 2004   821029      6.083638e+05  24215.773390  2723209.0
# 2005   821134      5.857052e+05  22855.152110  2557811.0
# 2006   821576      5.816662e+05  23251.241539  2566676.0
# 2007   823468      6.097132e+05  25156.613100  2847225.0
# 2008   824289      6.385321e+05  24501.923584  2740795.0
# 2009   825116      6.025347e+05  24088.070167  2704664.0
# 2010   826232      5.703932e+05  27807.854038  3367372.0
# 2011   827838      5.534092e+05  25253.636361  2883832.0
# 2012   830281      5.402664e+05  25987.736567  3016445.0
# 2013   831727      5.349988e+05  26058.804450  3003967.0

# %%
train_df.groupby('Year').count()
# Out:
#       PlaceID  AverageLandPrice  MeanLight  SumLight
# Year
# 1992      900               900        900       900
# 1993      951               951        951       951
# 1994      976               976        976       976
# 1995      982               982        982       982
# 1996      986               986        986       986
# 1997      990               990        990       990
# 1998      993               993        993       993
# 1999      995               995        995       995
# 2000      999               999        999       999
# 2001     1001              1001       1001      1001
# 2002     1001              1001       1001      1001
# 2003     1003              1003       1003      1003
# 2004     1004              1004       1004      1004
# 2005     1005              1005       1005      1005
# 2006     1006              1006       1006      1006
# 2007     1009              1009       1009      1009
# 2008     1010              1010       1010      1010
# 2009     1011              1011       1011      1011
# 2010     1012              1012       1012      1012
# 2011     1014              1014       1014      1014
# 2012     1017              1017       1017      1017
# 2013     1018              1018       1018      1018

# %%
fig, ax = plt.subplots(figsize=(8, 5))
RainCloud(data=train_df, y='AverageLandPrice', orient='h', ax=ax)
ax.grid()

# %%
train_df['log_AverageLandPrice'] = np.log10(train_df['AverageLandPrice'] + 1)
fig, ax = plt.subplots(figsize=(8,5))
RainCloud(data=train_df, y='log_AverageLandPrice', orient='h', ax=ax)
ax.grid()
